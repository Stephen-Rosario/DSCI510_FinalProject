# %%
from src.main import run_pipeline

# %%
run_pipeline()
# Out:
# === Student Performance Pipeline ===
# Loading UCI student datasets...
# Loaded dataset with 1044 rows and 33 columns.
# Preprocessing data...
# Fetching macro indicators from the World Bank API...
# World Bank macro features merged into dataset.
# Splitting data and training model...
# Evaluating model...
#
# MODEL ACCURACY: 1.0000
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      average       1.00      1.00      1.00        99
#    excellent       1.00      1.00      1.00        23
#         poor       1.00      1.00      1.00        87
#
#     accuracy                           1.00       209
#    macro avg       1.00      1.00      1.00       209
# weighted avg       1.00      1.00      1.00       209
#
#
# Confusion Matrix:
# [[99  0  0]
#  [ 0 23  0]
#  [ 0  0 87]]
# Generating visualizations...
# Running t-test (Internet vs. No Internet)...
# T-Test → t=3.4690, p=0.0006
#
# Pipeline complete. All plots saved to the 'results' folder.
